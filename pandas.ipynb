# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.head(30)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1                     I am a developer by profession      Yes
# 1            2                     I am a developer by profession       No
# 2            3                        I code primarily as a hobby      Yes
# 3            4                     I am a developer by profession      Yes
# 4            5  I used to be a developer by profession, but no...      Yes
# 5            6                     I am a developer by profession       No
# 6            7                     I am a developer by profession      Yes
# 7            8                     I am a developer by profession      Yes
# 8            9                     I am a developer by profession       No
# 9           10                     I am a developer by profession      Yes
# 10          11                     I am a developer by profession      Yes
# ...

# %%
##select column
df["Age1stCode"]
# Out:
# 0         13
# 1         19
# 2         15
# 3         18
# 4         16
#         ...
# 64456     16
# 64457    NaN
# 64458    NaN
# 64459    NaN
# 64460    NaN
# Name: Age1stCode, Length: 64461, dtype: object

# %%
##select multiple columns 
df[["MainBranch","Hobbyist"]]
# Out:
#                                               MainBranch Hobbyist
# 0                         I am a developer by profession      Yes
# 1                         I am a developer by profession       No
# 2                            I code primarily as a hobby      Yes
# 3                         I am a developer by profession      Yes
# 4      I used to be a developer by profession, but no...      Yes
# ...                                                  ...      ...
# 64456                                                NaN      Yes
# 64457                                                NaN      Yes
# 64458                                                NaN      Yes
# 64459                                                NaN      Yes
# 64460                                                NaN      Yes
#
# [64461 rows x 2 columns]

# %%
##iloc 
df.iloc[0:6,3:5]
# Out:
#     Age Age1stCode
# 0   NaN         13
# 1   NaN         19
# 2   NaN         15
# 3  25.0         18
# 4  31.0         16
# 5   NaN         14

# %%
#loc
df.loc[0:5,["MainBranch","Age1stCode"]]
# Out:
#                                           MainBranch Age1stCode
# 0                     I am a developer by profession         13
# 1                     I am a developer by profession         19
# 2                        I code primarily as a hobby         15
# 3                     I am a developer by profession         18
# 4  I used to be a developer by profession, but no...         16
# 5                     I am a developer by profession         14

# %%
##index 
df.set_index("MainBranch")
# Out:
#                                                     Respondent Hobbyist   Age  \
# MainBranch
# I am a developer by profession                               1      Yes   NaN
# I am a developer by profession                               2       No   NaN
# I code primarily as a hobby                                  3      Yes   NaN
# I am a developer by profession                               4      Yes  25.0
# I used to be a developer by profession, but no ...           5      Yes  31.0
# ...                                                        ...      ...   ...
# NaN                                                      64858      Yes   NaN
# NaN                                                      64867      Yes   NaN
# NaN                                                      64898      Yes   NaN
# NaN                                                      64925      Yes   NaN
# NaN                                                      65112      Yes   NaN
#
# ...

# %%
###reset index 
df.reset_index()
# Out:
#        index  Respondent                                         MainBranch  \
# 0          0           1                     I am a developer by profession
# 1          1           2                     I am a developer by profession
# 2          2           3                        I code primarily as a hobby
# 3          3           4                     I am a developer by profession
# 4          4           5  I used to be a developer by profession, but no...
# ...      ...         ...                                                ...
# 64456  64456       64858                                                NaN
# 64457  64457       64867                                                NaN
# 64458  64458       64898                                                NaN
# 64459  64459       64925                                                NaN
# 64460  64460       65112                                                NaN
#
# ...

# %%
##filters 
filter=((df["Age"]>20) & (df["Country"]=="Germany"))

# %%
##show filters
df.loc[filter,df.columns] ###show all columns
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 22             23          I am a developer by profession      Yes  27.0
# 23             24          I am a developer by profession      Yes  45.0
# 33             34          I am a developer by profession      Yes  29.0
# 104           106          I am a developer by profession      Yes  24.0
# 109           111  I am a student who is learning to code      Yes  25.0
# ...           ...                                     ...      ...   ...
# 61917       63201          I am a developer by profession      Yes  36.0
# 64234       19409                                     NaN      Yes  27.0
# 64239       19751                                     NaN      Yes  24.0
# 64277       30238                                     NaN      Yes  31.0
# 64336       42851                                     NaN      Yes  43.0
#
#       Age1stCode CompFreq  CompTotal  ConvertedComp  Country   CurrencyDesc  \
# ...

# %%
##filters using list 
liste_of_Countrys=["Germany","Albania","Spain"]
filter=df["Country"].isin(liste_of_Countrys)
df.loc[filter,df.columns]
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0               1  I am a developer by profession      Yes   NaN         13
# 3               4  I am a developer by profession      Yes  25.0         18
# 5               6  I am a developer by profession       No   NaN         14
# 11             12  I am a developer by profession       No  49.0         42
# 19             20  I am a developer by profession      Yes  40.0         18
# ...           ...                             ...      ...   ...        ...
# 64380       52163                             NaN      Yes   NaN         14
# 64402       56263                             NaN      Yes   NaN         14
# 64426       60134                             NaN      Yes  22.0         10
# 64429       61031                             NaN      Yes   NaN         23
# 64460       65112                             NaN      Yes   NaN        NaN
#
# ...

# %%
import numpy as np
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df1=pd.DataFrame(exam_data)
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df1
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
##update
df1.columns=[x.lower() for x in df1.columns]

# %%
df1
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
##replace 
df1.columns=df1.columns.str.replace("NAME","name")

# %%
df1
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
##rename
df1.rename(columns={"name":"NAME "})
# Out:
#        NAME   score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
##UPDATE ROWS
df1.loc[2]=["anas",20,1,"yes"]

# %%
df1
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2       anas   20.0         1     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
##update_by_filter
filter=df1["name"]=="anas"

# %%
df1.loc[filter,"name"]="ANAS"

# %%
df1
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2       ANAS   20.0         1     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
df1["name"]=df1["name"].str.lower()+"1"

# %%
df1
# Out:
#          name  score  attempts qualify
# 0  anastasia1   12.5         1     yes
# 1       dima1    9.0         3      no
# 2       anas1   20.0         1     yes
# 3      james1    NaN         3      no
# 4      emily1    9.0         2      no
# 5    michael1   20.0         3     yes
# 6    matthew1   14.5         1     yes
# 7      laura1    NaN         1      no
# 8      kevin1    8.0         2      no
# 9      jonas1   19.0         1     yes

# %%
##apply 
df1["name"].apply(len)
# Out:
# 0    10
# 1     5
# 2     5
# 3     6
# 4     6
# 5     8
# 6     8
# 7     6
# 8     6
# 9     6
# Name: name, dtype: int64

# %%
def len_x(x):
    return len(x)

# %%
df1["name"].apply(len_x)
# Out:
# 0    10
# 1     5
# 2     5
# 3     6
# 4     6
# 5     8
# 6     8
# 7     6
# 8     6
# 9     6
# Name: name, dtype: int64

# %%
#applymap
df1.applymap(lambda x: len(str(x)))
# Out:
#    name  score  attempts  qualify
# 0    10      4         1        3
# 1     5      3         1        2
# 2     5      4         1        3
# 3     6      3         1        2
# 4     6      3         1        2
# 5     8      4         1        3
# 6     8      4         1        3
# 7     6      3         1        2
# 8     6      3         1        2
# 9     6      4         1        3

# %%
##replace
df1["name"].replace({"dima1":"dima","kevin1":"kevin"})
# Out:
# 0    anastasia1
# 1          dima
# 2         anas1
# 3        james1
# 4        emily1
# 5      michael1
# 6      matthew1
# 7        laura1
# 8         kevin
# 9        jonas1
# Name: name, dtype: object

# %%
##add column 
import random 
for i in range(df1.shape[0]):
    df1.loc[i,"nickname"]=df1.loc[i,"name"]+str(random.randint(0,10))

# %%
df1
# Out:
#          name  score  attempts qualify     nickname
# 0  anastasia1   12.5         1     yes  anastasia11
# 1       dima1    9.0         3      no       dima10
# 2       anas1   20.0         1     yes       anas10
# 3      james1    NaN         3      no      james11
# 4      emily1    9.0         2      no      emily12
# 5    michael1   20.0         3     yes    michael15
# 6    matthew1   14.5         1     yes    matthew18
# 7      laura1    NaN         1      no      laura15
# 8      kevin1    8.0         2      no      kevin12
# 9      jonas1   19.0         1     yes      jonas14

# %%
df1["score"]=df1["score"].apply(str)

# %%
df2=df1.loc[4:5]

# %%
df2
# Out:
#        name score  attempts qualify   nickname
# 4    emily1   9.0         2      no    emily12
# 5  michael1  20.0         3     yes  michael15

# %%
df1.append(df2)
# Out:
#          name score  attempts qualify     nickname
# 0  anastasia1  12.5         1     yes  anastasia11
# 1       dima1   9.0         3      no       dima10
# 2       anas1  20.0         1     yes       anas10
# 3      james1   nan         3      no      james11
# 4      emily1   9.0         2      no      emily12
# 5    michael1  20.0         3     yes    michael15
# 6    matthew1  14.5         1     yes    matthew18
# 7      laura1   nan         1      no      laura15
# 8      kevin1   8.0         2      no      kevin12
# 9      jonas1  19.0         1     yes      jonas14
# 4      emily1   9.0         2      no      emily12
# 5    michael1  20.0         3     yes    michael15

# %%
df1["name_score"]=df1["name"]+df1["score"]

# %%
df1
# Out:
#          name score  attempts qualify     nickname      name_score
# 0  anastasia1  12.5         1     yes  anastasia11  anastasia112.5
# 1       dima1   9.0         3      no       dima10        dima19.0
# 2       anas1  20.0         1     yes       anas10       anas120.0
# 3      james1   nan         3      no      james11       james1nan
# 4      emily1   9.0         2      no      emily12       emily19.0
# 5    michael1  20.0         3     yes    michael15    michael120.0
# 6    matthew1  14.5         1     yes    matthew18    matthew114.5
# 7      laura1   nan         1      no      laura15       laura1nan
# 8      kevin1   8.0         2      no      kevin12       kevin18.0
# 9      jonas1  19.0         1     yes      jonas14      jonas119.0

# %%
##remove column 
df1=df1.drop(columns=["name_score"])

# %%
df1
# Out:
#          name score  attempts qualify     nickname
# 0  anastasia1  12.5         1     yes  anastasia11
# 1       dima1   9.0         3      no       dima10
# 2       anas1  20.0         1     yes       anas10
# 3      james1   nan         3      no      james11
# 4      emily1   9.0         2      no      emily12
# 5    michael1  20.0         3     yes    michael15
# 6    matthew1  14.5         1     yes    matthew18
# 7      laura1   nan         1      no      laura15
# 8      kevin1   8.0         2      no      kevin12
# 9      jonas1  19.0         1     yes      jonas14

# %%
df1
# Out:
#          name score  attempts qualify     nickname
# 0  anastasia1  12.5         1     yes  anastasia11
# 1       dima1   9.0         3      no       dima10
# 2       anas1  20.0         1     yes       anas10
# 3      james1   nan         3      no      james11
# 4      emily1   9.0         2      no      emily12
# 5    michael1  20.0         3     yes    michael15
# 6    matthew1  14.5         1     yes    matthew18
# 7      laura1   nan         1      no      laura15
# 8      kevin1   8.0         2      no      kevin12
# 9      jonas1  19.0         1     yes      jonas14

# %%
df1.drop(index=9)
# Out:
#          name score  attempts qualify     nickname
# 0  anastasia1  12.5         1     yes  anastasia11
# 1       dima1   9.0         3      no       dima10
# 2       anas1  20.0         1     yes       anas10
# 3      james1   nan         3      no      james11
# 4      emily1   9.0         2      no      emily12
# 5    michael1  20.0         3     yes    michael15
# 6    matthew1  14.5         1     yes    matthew18
# 7      laura1   nan         1      no      laura15
# 8      kevin1   8.0         2      no      kevin12

# %%
##remove with filter
filter=df1["name"]=="kevin1"

# %%
df1.loc[filter]
# Out:
#      name score  attempts qualify nickname
# 8  kevin1   8.0         2      no  kevin12

# %%
df1=df1.drop(df1[filter].index,axis=0)

# %%
df1
# Out:
#          name score  attempts qualify     nickname
# 0  anastasia1  12.5         1     yes  anastasia11
# 1       dima1   9.0         3      no       dima10
# 2       anas1  20.0         1     yes       anas10
# 3      james1   nan         3      no      james11
# 4      emily1   9.0         2      no      emily12
# 5    michael1  20.0         3     yes    michael15
# 6    matthew1  14.5         1     yes    matthew18
# 7      laura1   nan         1      no      laura15
# 9      jonas1  19.0         1     yes      jonas14

# %%
##sorting 
df1["score"]=df1["score"].apply(float)
df1.sort_values(by="score")
#reverse 
df1.sort_values(by="score",ascending=False )
# Out:
#          name  score  attempts qualify     nickname
# 2       anas1   20.0         1     yes       anas10
# 5    michael1   20.0         3     yes    michael15
# 9      jonas1   19.0         1     yes      jonas14
# 6    matthew1   14.5         1     yes    matthew18
# 0  anastasia1   12.5         1     yes  anastasia11
# 1       dima1    9.0         3      no       dima10
# 4      emily1    9.0         2      no      emily12
# 3      james1    NaN         3      no      james11
# 7      laura1    NaN         1      no      laura15

# %%
##nlargest and nsmalest 
df1.nlargest(3,"score")
# Out:
#        name  score  attempts qualify   nickname
# 2     anas1   20.0         1     yes     anas10
# 5  michael1   20.0         3     yes  michael15
# 9    jonas1   19.0         1     yes    jonas14

# %%
df1.nsmallest(3,"score")
# Out:
#          name  score  attempts qualify     nickname
# 1       dima1    9.0         3      no       dima10
# 4      emily1    9.0         2      no      emily12
# 0  anastasia1   12.5         1     yes  anastasia11

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
#grouping
country_group=df.groupby(["Country"])

# %%
# Out:
# Country
# Afghanistan                              80
# Albania                                  53
# Algeria                                  90
# Andorra                                  13
# Angola                                    9
#                                        ...
# Venezuela, Bolivarian Republic of...     70
# Viet Nam                                362
# Yemen                                     7
# Zambia                                   20
# Zimbabwe                                 31
# Name: MainBranch, Length: 183, dtype: int64

# %%
##aggregate 
# count	Number of non-null observations
# sum	Sum of values
# mean	Mean of values
# mad	Mean absolute deviation
# median	Arithmetic median of values
# min	Minimum
# max	Maximum
# mode	Mode
# abs	Absolute Value
# prod	Product of values
# std	Unbiased standard deviation
# var	Unbiased variance
# sem	Unbiased standard error of the mean
# skew	Unbiased skewness (3rd moment)
# kurt	Unbiased kurtosis (4th moment)
# quantile	Sample quantile (value at %)
# cumsum	Cumulative sum
# cumprod	Cumulative product
# cummax	Cumulative maximum
# cummin	Cumulative minimum

# %%
##value_counts
country_group["MainBranch"].value_counts().loc["Afghanistan"]
# Out:
# MainBranch
# I am a developer by profession                                                   47
# I am a student who is learning to code                                           22
# I used to be a developer by profession, but no longer am                          5
# I am not primarily a developer, but I write code sometimes as part of my work     3
# I code primarily as a hobby                                                       3
# Name: MainBranch, dtype: int64

# %%
country_group.agg(
{
        # Find the min, max, and sum of the duration column
        'Age': [min, max, sum],
        # find the number of network type entries
        'MainBranch': "count",
       
    })
# Out:
#                                        Age               MainBranch
#                                        min   max     sum      count
# Country
# Afghanistan                           15.0  32.0   518.0         80
# Albania                               16.0  38.0   803.0         53
# Algeria                               15.0  99.0  1429.0         90
# Andorra                               30.0  51.0   117.0         13
# Angola                                22.0  69.0   120.0          9
# ...                                    ...   ...     ...        ...
# Venezuela, Bolivarian Republic of...  17.0  66.0  1624.0         70
# Viet Nam                               5.0  89.0  4234.0        362
# Yemen                                 27.0  35.0    62.0          7
# Zambia                                20.0  46.0   282.0         20
# Zimbabwe                              19.0  33.0   486.0         31
#
# [183 rows x 4 columns]

# %%
##DROP NA
df.dropna(axis='columns')
# Out:
#        Respondent
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
# ...           ...
# 64456       64858
# 64457       64867
# 64458       64898
# 64459       64925
# 64460       65112
#
# [64461 rows x 1 columns]

# %%
df.dropna(subset=["Age"])
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 64426       60134                                                NaN      Yes
# 64427       60149                                                NaN      Yes
# 64430       61111                                                NaN      Yes
# 64433       61561                                                NaN      Yes
# 64441       62834                                                NaN      Yes
#
# ...

# %%
###datatime 
df2=pd.read_csv("date.csv")

# %%
df2
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0    2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ..                ...     ...     ...     ...     ...     ...         ...
# 129  2020-03-08 11-AM  ETHUSD  231.91  232.80  230.85  231.63   797045.86
# 130  2020-03-08 10-AM  ETHUSD  230.05  232.00  229.15  231.91   870399.78
# 131  2020-03-08 09-AM  ETHUSD  229.23  231.10  229.23  230.05   317255.88
# 132  2020-03-08 08-AM  ETHUSD  230.16  230.16  228.72  229.23   329689.71
# 133  2020-03-08 07-AM  ETHUSD  229.29  230.62  229.23  230.16   324167.86
#
# [134 rows x 7 columns]

# %%
df2["Date"]=pd.to_datetime(df2["Date"], format="%Y-%m-%d %I-%p")

# %%
df2
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0   2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1   2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2   2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3   2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4   2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ..                  ...     ...     ...     ...     ...     ...         ...
# 129 2020-03-08 11:00:00  ETHUSD  231.91  232.80  230.85  231.63   797045.86
# 130 2020-03-08 10:00:00  ETHUSD  230.05  232.00  229.15  231.91   870399.78
# 131 2020-03-08 09:00:00  ETHUSD  229.23  231.10  229.23  230.05   317255.88
# 132 2020-03-08 08:00:00  ETHUSD  230.16  230.16  228.72  229.23   329689.71
# 133 2020-03-08 07:00:00  ETHUSD  229.29  230.62  229.23  230.16   324167.86
#
# [134 rows x 7 columns]

# %%
df2["Date"].min()
# Out:
# Timestamp('2020-03-08 07:00:00')

# %%
df2.loc[0,"Date"].hour
# Out:
# 20

# %%
# datetime.year
# Between MINYEAR and MAXYEAR inclusive.

# datetime.month
# Between 1 and 12 inclusive.

# datetime.day
# Between 1 and the number of days in the given month of the given year.

# datetime.hour
# In range(24).

# datetime.minute
# In range(60).

# datetime.second
# In range(60).

# %%
df2.loc[0,"Date"].year
# Out:
# 2020

# %%
df2.loc[0,"Date"].date()
# Out:
# datetime.date(2020, 3, 13)

# %%
df2.loc[0,"Date"]-df2.loc[1,"Date"]
# Out:
# Timedelta('0 days 01:00:00')
